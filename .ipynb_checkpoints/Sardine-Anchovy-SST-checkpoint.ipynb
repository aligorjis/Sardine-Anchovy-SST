# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd  
from sklearn.metrics import f1_score
from sklearn.linear_model import LinearRegression
import sklearn
import math
import networkx as nx
from scipy import stats
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
#pd.set_option('display.width', 1000)
from sklearn.ensemble import RandomForestRegressor
from numpy import trapz
import scipy
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from copy import copy, deepcopy
# %matplotlib inline
plt.rcParams["figure.figsize"] = (16,3)

# %% [markdown]
# Sea surface temperature (SST) was measured at shore stations: Scripps Pier and Newport Pier (data available from: http://shorestation.ucsd.edu/active/index_active.html). monthly means were averaged to form yearly time series, and the final time series consisted of 3-year running averages for the SST.

# %%
scripps = pd.read_csv("SIO.txt",delimiter=' ',encoding='utf-8')

# %%
scripps.head()
# Out:
#      YEAR  MONTH   DAY  TIME_PST  TIME_FLAG  SURF_TEMP_C  SURF_FLAG  \
# 0  1916.0    8.0  22.0       NaN        NaN         19.5        0.0
# 1  1916.0    8.0  23.0       NaN        NaN         19.9        0.0
# 2  1916.0    8.0  24.0       NaN        NaN         19.7        0.0
# 3  1916.0    8.0  25.0       NaN        NaN         19.7        0.0
# 4  1916.0    8.0  26.0       NaN        NaN         19.5        0.0
#
#    BOT_TEMP_C  BOT_FLAG
# 0         NaN       NaN
# 1         NaN       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4         NaN       NaN

# %%
scripps_monthly=scripps[["YEAR","MONTH","SURF_TEMP_C"]].groupby(["YEAR","MONTH"]).mean().reset_index()

# %%
scripps_monthly.head()
# Out:
#      YEAR  MONTH  SURF_TEMP_C
# 0  1916.0    8.0    19.311111
# 1  1916.0    9.0    18.130769
# 2  1916.0   10.0    15.680000
# 3  1916.0   11.0    14.208000
# 4  1916.0   12.0    13.128000

# %%
scripps_yearly=scripps[["YEAR","SURF_TEMP_C"]].groupby(["YEAR"]).mean().reset_index()

# %%
scripps_yearly.head(12)
# Out:
#       YEAR  SURF_TEMP_C
# 0   1916.0    15.641818
# 1   1917.0    16.742715
# 2   1918.0    17.385113
# 3   1919.0    16.810032
# 4   1920.0    16.576177
# 5   1921.0    16.536223
# 6   1922.0    16.532899
# 7   1923.0    17.327723
# 8   1924.0    16.436808
# 9   1925.0    17.032329
# 10  1926.0    18.081096
# 11  1927.0    16.880274

# %% [markdown]
# monthly means were averaged to form yearly time series, and the final time series consisted of 3-year running averages for the SST.

# %%
scripps_yearly.rolling(window=3).mean()
# Out:
#        YEAR  SURF_TEMP_C
# 0       NaN          NaN
# 1       NaN          NaN
# 2    1917.0    16.589882
# 3    1918.0    16.979287
# 4    1919.0    16.923774
# 5    1920.0    16.640811
# 6    1921.0    16.548433
# 7    1922.0    16.798948
# 8    1923.0    16.765810
# 9    1924.0    16.932286
# 10   1925.0    17.183411
# 11   1926.0    17.331233
# 12   1927.0    17.235484
# 13   1928.0    16.944251
# 14   1929.0    17.141394
# 15   1930.0    17.731116
# 16   1931.0    17.436047
# 17   1932.0    16.836986
# 18   1933.0    16.516259
# 19   1934.0    16.650597
# 20   1935.0    17.301076
# 21   1936.0    17.136871
# 22   1937.0    17.126004
# 23   1938.0    16.987763
# 24   1939.0    17.090076
# 25   1940.0    17.417017
# 26   1941.0    17.356286
# 27   1942.0    17.239635
# 28   1943.0    16.847400
# 29   1944.0    16.714524
# 30   1945.0    16.661556
# 31   1946.0    16.796438
# 32   1947.0    16.614443
# 33   1948.0    16.511430
# 34   1949.0    16.350243
# 35   1950.0    16.537743
# 36   1951.0    16.462739
# 37   1952.0    16.417041
# 38   1953.0    16.509826
# 39   1954.0    16.580636
# 40   1955.0    16.616846
# 41   1956.0    16.766545
# 42   1957.0    17.207613
# 43   1958.0    17.879118
# 44   1959.0    17.630736
# 45   1960.0    17.192400
# 46   1961.0    16.477234
# 47   1962.0    16.593242
# 48   1963.0    16.558776
# 49   1964.0    16.653753
# 50   1965.0    16.670922
# 51   1966.0    16.840365
# 52   1967.0    16.975936
# 53   1968.0    16.856119
# 54   1969.0    16.759918
# 55   1970.0    16.511836
# 56   1971.0    16.586545
# 57   1972.0    16.522015
# 58   1973.0    16.616343
# 59   1974.0    16.167204
# 60   1975.0    16.434721
# 61   1976.0    16.693635
# 62   1977.0    17.327971
# 63   1978.0    17.191487
# 64   1979.0    16.979595
# 65   1980.0    17.039532
# 66   1981.0    17.138151
# 67   1982.0    17.589663
# 68   1983.0    17.815116
# 69   1984.0    17.841937
# 70   1985.0    17.757047
# 71   1986.0    17.513370
# 72   1987.0    17.442649
# 73   1988.0    17.266822
# 74   1989.0    17.377088
# 75   1990.0    17.362076
# 76   1991.0    17.719240
# 77   1992.0    17.876322
# 78   1993.0    18.247732
# 79   1994.0    18.078273
# 80   1995.0    17.924263
# 81   1996.0    18.335802
# 82   1997.0    18.434267
# 83   1998.0    17.970613
# 84   1999.0    17.414128
# 85   2000.0    17.200301
# 86   2001.0    17.489687
# 87   2002.0    17.508100
# 88   2003.0    17.819691
# 89   2004.0    18.120513
# 90   2005.0    18.261701
# 91   2006.0    18.025076
# 92   2007.0    17.841175
# 93   2008.0    17.851203
# 94   2009.0    17.708846
# 95   2010.0    17.466453
# 96   2011.0    17.299279
# 97   2012.0    17.424105
# 98   2013.0    18.237394
# 99   2014.0    18.877219
# 100  2015.0    19.236019
# 101  2016.0    18.948083
# 102  2017.0    18.780512
# 103  2018.0    18.068514

# %%
scripps_yearly=scripps_yearly[(scripps_yearly["YEAR"]>=1928) & (scripps_yearly["YEAR"]<=2006)]

# %%
scripps_yearly.plot("YEAR","SURF_TEMP_C")

# %%
newport = pd.read_csv("Newport.csv",delimiter=' ',encoding='utf-8')

# %%
newport.head(12)
# Out:
#     YEAR  MONTH  DAY  TIME_PST TIME_FLAG  SURF_TEMP_C  TEMP_FLAG
# 0   1924     11    1       NaN       NaN          NaN        NaN
# 1   1924     11    2       NaN       NaN          NaN        NaN
# 2   1924     11    3       NaN       NaN          NaN        NaN
# 3   1924     11    4       NaN       NaN          NaN        NaN
# 4   1924     11    5       NaN       NaN          NaN        NaN
# 5   1924     11    6       NaN       NaN          NaN        NaN
# 6   1924     11    7       NaN       NaN          NaN        NaN
# 7   1924     11    8       NaN       NaN          NaN        NaN
# 8   1924     11    9       NaN       NaN          NaN        NaN
# 9   1924     11   10       NaN       NaN          NaN        NaN
# 10  1924     11   11       NaN       NaN          NaN        NaN
# 11  1924     11   12       NaN       NaN         14.0        NaN

# %%
newport_monthly=newport[["YEAR","MONTH","SURF_TEMP_C"]].groupby(["YEAR","MONTH"]).mean().reset_index()

# %%
newport_yearly=newport[["YEAR","SURF_TEMP_C"]].groupby(["YEAR"]).mean().reset_index()

# %%
newport_yearly.head(12)
# Out:
#     YEAR  SURF_TEMP_C
# 0   1924    13.744186
# 1   1925    16.149359
# 2   1926    17.297692
# 3   1927    15.835776
# 4   1928    17.210674
# 5   1929    16.536462
# 6   1930    17.060831
# 7   1931    18.091507
# 8   1932    16.013388
# 9   1933    15.170685
# 10  1934    16.991781
# 11  1935    16.177260

# %% [markdown]
# monthly means were averaged to form yearly time series, and the final
# time series consisted of 3-year running averages for the SST.

# %%
newport_yearly.rolling(window=3).mean()
# Out:
#       YEAR  SURF_TEMP_C
# 0      NaN          NaN
# 1      NaN          NaN
# 2   1925.0    15.730412
# 3   1926.0    16.427609
# 4   1927.0    16.781381
# 5   1928.0    16.527637
# 6   1929.0    16.935989
# 7   1930.0    17.229600
# 8   1931.0    17.055242
# 9   1932.0    16.425193
# 10  1933.0    16.058618
# 11  1934.0    16.113242
# 12  1935.0    16.736530
# 13  1936.0    16.614247
# 14  1937.0    16.677321
# 15  1938.0    16.625997
# 16  1939.0    16.792368
# 17  1940.0    17.223996
# 18  1941.0    17.203448
# 19  1942.0    17.098904
# 20  1943.0    16.571344
# 21  1944.0    16.398193
# 22  1945.0    16.346412
# 23  1946.0    16.585662
# 24  1947.0    16.362797
# 25  1948.0    16.141793
# 26  1949.0    15.832660
# 27  1950.0    15.884658
# 28  1951.0    15.661714
# 29  1952.0    15.548837
# 30  1953.0    15.293221
# 31  1954.0    15.307397
# 32  1955.0    15.366568
# 33  1956.0    15.827684
# 34  1957.0    16.517730
# 35  1958.0    17.192257
# 36  1959.0    17.132237
# 37  1960.0    16.646758
# 38  1961.0    16.050397
# 39  1962.0    16.197886
# 40  1963.0    16.205648
# 41  1964.0    16.394629
# 42  1965.0    16.387506
# 43  1966.0    16.576061
# 44  1967.0    16.555999
# 45  1968.0    16.428939
# 46  1969.0    16.256913
# 47  1970.0    16.019789
# 48  1971.0    16.049809
# 49  1972.0    16.049307
# 50  1973.0    16.086842
# 51  1974.0    15.713599
# 52  1975.0    15.982176
# 53  1976.0    16.249300
# 54  1977.0    16.865855
# 55  1978.0    16.564222
# 56  1979.0    16.352795
# 57  1980.0    16.249810
# 58  1981.0    16.374600
# 59  1982.0    16.917717
# 60  1983.0    17.243873
# 61  1984.0    17.244147
# 62  1985.0    17.010391
# 63  1986.0    16.767669
# 64  1987.0    16.795332
# 65  1988.0    16.769675
# 66  1989.0    16.766298
# 67  1990.0    16.661623
# 68  1991.0    16.855373
# 69  1992.0    17.043451
# 70  1993.0    17.371104
# 71  1994.0    16.791776
# 72  1995.0    16.220585
# 73  1996.0    16.367754
# 74  1997.0    16.608360
# 75  1998.0    16.292168
# 76  1999.0    15.725686
# 77  2000.0    15.276465
# 78  2001.0    15.775511
# 79  2002.0    15.697217
# 80  2003.0    16.114714
# 81  2004.0    16.047293
# 82  2005.0    16.163947
# 83  2006.0    16.175090
# 84  2007.0    16.180554
# 85  2008.0    16.403469
# 86  2009.0    16.200747
# 87  2010.0    16.136758
# 88  2011.0    16.167053
# 89  2012.0    16.463814
# 90  2013.0    17.697005
# 91  2014.0    18.417466
# 92  2015.0    18.830205
# 93  2016.0    18.193992
# 94  2017.0    17.942925
# 95  2018.0    16.962904

# %%
newport_yearly=newport_yearly[(newport_yearly["YEAR"]>=1928) & (newport_yearly["YEAR"]<=2006)]

# %%
newport_yearly.plot("YEAR","SURF_TEMP_C")

# %% [markdown]
# California landings data for Pacific sardine (Sardinops sagax) and northern anchovy (Engraulis mordax) were taken from two sources: 1. (1928 – 2002) NOAA Southwest Fisheries Science Center (https://coastwatch.pfeg.noaa.gov/erddap/search/index.html?page=1&itemsPerPage=1000&searchFor=erdCAMarCat) 2. (2003 – 2006) California Department of Fish and Game (https://oceanview.pfeg.noaa.gov/erddap/search/index.html?page=1&itemsPerPage=1000&searchFor=CA_mkt_catch)

# %% [markdown]
# # sardine

# %%
sardine1 = pd.read_csv("sardine.txt",delimiter=' ',encoding='utf-8').reset_index()[["time","landings"]]
sardine1.columns=["YEAR","landings"]
sardine1.head()
# Out:
#    YEAR  landings
# 0  1928  40874524
# 1  1928  95819881
# 2  1928  42943442
# 3  1928   4195019
# 4  1928   3380067

# %%
sardine1_yearly=sardine1.groupby("YEAR").sum().reset_index()
sardine1_yearly.head()
# Out:
#    YEAR   landings
# 0  1928  420269665
# 1  1929  651771904
# 2  1930  494450747
# 3  1931  301307801
# 4  1932  312171650

# %%
sardine1_yearly.plot("YEAR","landings")

# %%
sardine2= pd.read_csv("sardine2.txt",skiprows=2,delimiter="\t",names=["YEAR","fish","landings","port"])
sardine2.loc[:,"YEAR"]=sardine2.loc[:,"YEAR"].apply(lambda x:int(x[0:4]))
sardine2.head()
# Out:
#    YEAR              fish  landings           port
# 0  2003  Sardine, Pacific  17432494       Monterey
# 1  2003  Sardine, Pacific   5221404  Santa Barbara
# 2  2003  Sardine, Pacific     61930      San Diego
# 3  2003  Sardine, Pacific       250  San Francisco
# 4  2004  Sardine, Pacific  34047402       Monterey

# %%
sardine2=sardine2[(sardine2["YEAR"]>=2003) & (sardine2["YEAR"]<=2006)]

# %%
sardine2_yearly=sardine2[["YEAR","landings"]].groupby(["YEAR"]).sum().reset_index()

# %%
sardine2_yearly.plot("YEAR","landings")

# %%
sardine_yearly=pd.concat([sardine1_yearly,sardine2_yearly],axis=0)

# %%
sardine_yearly.plot("YEAR","landings")

# %%
anchovy1 = pd.read_csv("Anchovy.txt",delimiter=' ',encoding='utf-8',).reset_index()[["time","landings"]]
anchovy1.columns=["YEAR","landings"]

anchovy1.head()
# Out:
#    YEAR  landings
# 0  1928      1190
# 1  1928       155
# 2  1928         0
# 3  1928     23137
# 4  1928    187335

# %%
anchovy1_yearly=anchovy1.groupby("YEAR").sum().reset_index()
anchovy1_yearly.head()
# Out:
#    YEAR  landings
# 0  1928    357470
# 1  1929    382445
# 2  1930    319561
# 3  1931    307494
# 4  1932    299217

# %%
anchovy1_yearly.plot("YEAR","landings")

# %%
anchovy2= pd.read_csv("Anchovy2.txt",skiprows=2,delimiter="\t",names=["YEAR","fish","landings","port"])
anchovy2.loc[:,"YEAR"]=anchovy2.loc[:,"YEAR"].apply(lambda x:int(x[0:4]))
anchovy2.head()
# Out:
#    YEAR               fish   landings           port
# 0  2003  Anchovy, Northern  1555834.0       Monterey
# 1  2003  Anchovy, Northern  1378832.0  Santa Barbara
# 2  2003  Anchovy, Northern    29972.0      San Diego
# 3  2003  Anchovy, Northern        0.0  San Francisco
# 4  2004  Anchovy, Northern  8577584.0       Monterey

# %%
anchovy2=anchovy2[(anchovy2["YEAR"]>=2003) & (anchovy2["YEAR"]<=2006)]

# %%
anchovy2_yearly=anchovy2[["YEAR","landings"]].groupby(["YEAR"]).sum().reset_index()

# %%
anchovy2_yearly.plot("YEAR","landings")

# %%
anchovy_yearly=pd.concat([anchovy1_yearly,anchovy2_yearly],axis=0)

# %%
anchovy_yearly.plot("YEAR","landings")

# %% [markdown]
# #CCM tested for linkages between sardine and anchovy, sardine versus Scripps Pier SST, and anchovy versus Newport Pier SST.

# %%
A=pd.merge(sardine_yearly,anchovy_yearly, left_on='YEAR', right_on='YEAR')

# %%
B=pd.merge(A,newport_yearly, left_on='YEAR', right_on='YEAR')

# %%
ALL=pd.merge(B,scripps_yearly, left_on='YEAR', right_on='YEAR')

# %%
ALL.columns=["year","sardine","anchovy","newport","scripps"]

# %%
ALL
# Out:
#     year     sardine      anchovy    newport    scripps
# 0   1928   420269665     357470.0  17.210674  16.745082
# 1   1929   651771904     382445.0  16.536462  17.207397
# 2   1930   494450747     319561.0  17.060831  17.471703
# 3   1931   301307801     307494.0  18.091507  18.514247
# 4   1932   312171650     299217.0  16.013388  16.322192
# 5   1933   509797481     317292.0  15.170685  15.674521
# 6   1934   903633589     257505.0  16.991781  17.552066
# 7   1935   829508682     178970.0  16.177260  16.725205
# 8   1936   955525049     195122.0  17.040548  17.625956
# 9   1937   891430435     226229.0  16.624932  17.059452
# 10  1938   935611403     735144.0  16.366484  16.692603
# 11  1939  1160793581    2147901.0  16.886575  17.211233
# 12  1940   905973203    6317797.0  17.124044  17.366393
# 13  1941  1262480393    4105382.0  17.661370  17.673425
# 14  1942   969746997    1694290.0  16.824932  17.029041
# 15  1943   972269390    1570803.0  16.810411  17.016438
# 16  1944  1147207117    3891029.0  16.078689  16.496721
# 17  1945   845062774    1616880.0  16.305479  16.630411
# 18  1946   510759173    1921627.0  16.655068  16.857534
# 58      856444    3384779.0  16.945580  17.729670
# 59      968776    3063684.0  17.030579  17.574176
# 60     2619999    3258054.0  16.409836  17.024100
# 61     1844620    5399826.0  16.868611  17.202192
# 62     3668983    7073116.0  17.020448  17.904972
# 63    16727151    8848805.0  16.095810  16.979063
# 64    39553794    2477803.0  17.449862  18.273684
# 65    33830484    4315680.0  17.584680  18.376220
# 66    25669552    3934477.0  17.078771  18.093293
# 67    88585710    4157914.0  15.711878  17.765306
# 68    71767264    9738124.0  15.871105  17.914191
# 69    95436594   12603430.0  17.520278  19.327907
# 70    95162047    3212545.0  16.433699  18.060703
# 71   130469232   11434014.0  14.922527  16.523229
# 72   118307857   25908387.0  15.820833  17.658453
# 73   114224549   42309614.0  15.086034  17.419220
# 74   128520885   10236838.0  16.419668  17.391389
# 75    22716078    2964638.0  15.585950  17.713690
# 76    45300087   14650290.0  16.338525  18.353994
# 77    76173217   24646691.0  16.217403  18.293855
# 78   102683677   28198277.0  15.935912  18.137255

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %matplotlib inline

# %%
# %run lingam.py

# %%
#use kurtosis base ICA
lingam = LiNGAM()
lingam.fit(ALL)
# Out:
# anchovy ---|-2.180|---> sardine
# newport ---|192686893.267|---> sardine
# scripps ---|-238592658.965|---> sardine
# newport ---|-7419392.142|---> anchovy
# scripps ---|-23553311.958|---> anchovy
# newport ---|0.671|---> scripps
# array([[ 0.00000000e+00, -2.18046707e+00,  1.92686893e+08,
#         -2.38592659e+08],
#        [ 0.00000000e+00,  0.00000000e+00, -7.41939214e+06,
#         -2.35533120e+07],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  6.71125463e-01,
#          0.00000000e+00]])

# %%
#use neg-entropy base ICA(robuster than kurtosis base)
lingam = LiNGAM()
lingam.fit(ALL,use_sklearn=True)
# Out:
# anchovy ---|-2.180|---> sardine
# newport ---|192686893.267|---> sardine
# scripps ---|-238592658.965|---> sardine
# newport ---|-7419392.142|---> anchovy
# scripps ---|-23553311.958|---> anchovy
# newport ---|0.671|---> scripps
# c:\users\ali\python37\lib\site-packages\sklearn\decomposition\fastica_.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)
# array([[ 0.00000000e+00, -2.18046707e+00,  1.92686893e+08,
#         -2.38592659e+08],
#        [ 0.00000000e+00,  0.00000000e+00, -7.41939214e+06,
#         -2.35533120e+07],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  6.71125463e-01,
#          0.00000000e+00]])

# %% [markdown]
# The causalities discovered was simillar to causalities that the paper "Detecting Causality Complex Ecosystems data" written by Sugihara et al. which says: "signal between sardine and anchovy landings, indicating that sardines and anchovies do not interact. In addition, as expected, there is no detectable signature from either sardine or anchovy in the temperature manifold; obviously, neither sardines nor anchovies affect SST. However, there is clear asymmetric CCM between sardines and SST as well as between anchovies and SST,meaning that temperature information is encoded in both fishery time series. The recoverable temperature signature reveals a weak coupling of temperature to sardines and anchovies. Thus, although sardines and anchovies are not actually interacting, they are weakly forced by a common environmental driver, for which temperature is at least a viable proxy.
